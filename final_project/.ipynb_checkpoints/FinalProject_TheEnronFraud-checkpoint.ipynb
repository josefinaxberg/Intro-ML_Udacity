# %% [markdown]
# * * *
#
# <div align="Right">
#   ©    Josefin Axberg 2017<br>
#  </div>

# %% [markdown]
# # Final Project: Discovering the Enron Fraud

# %% [markdown]
# ## Introduction

# %% [markdown]
# In 2000, Enron was one of the largest companies in the United States. By 2002, it had collapsed into bankruptcy due to widespread corporate fraud. In the resulting Federal investigation, there was a significant amount of typically confidential information entered into public record, including tens of thousands of emails and detailed financial data for top executives. In this project, I will play detective, and put my new skills to use by building a person of interest identifier based on financial and email data made public as a result of the Enron scandal. I use email and financial data for 146 executives at Enron to identify persons of interest in the fraud case. A person of interest (POI) is someone who was indicted for fraud, settled with the government, or testified in exchange for immunity. This report documents the machine learning techniques used in building a POI identifier.
# There are four major steps in my project:
# 1. **Explore data**
# 2. **Feature engineering**
# 3. **Classifiers**
# 4. **Validation**

# %% [markdown]
# ![](enron.jpg)

# %%
import time
print("Today is %s" % time.strftime("%Y-%m-%d"))
# Out:
# Today is 2017-10-12

# %%
#!/usr/bin/python

import os
import pickle
import re
import sys
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

sys.path.append("../tools/")

from feature_format import featureFormat, targetFeatureSplit

# Features_list is a list of strings, each of which is a feature name.
# The first feature must be "poi".
features_list = ['poi']

# %% [markdown]
# Let me start with the loading of the data and see how it is structured.

# %%
# Load the dictionary containing the dataset
with open("final_project_dataset.pkl", "r") as data_file:
    data_dict = pickle.load(data_file)

my_dataset = data_dict
df_enron = pd.DataFrame(my_dataset) # Load pickle data to DataFrame for feature enginering etc
df_enron = df_enron.T               # Setting names as indexes and features as columns


df_enron.head()
# Out:
#                       bonus deferral_payments deferred_income director_fees  \
# ALLEN PHILLIP K     4175000           2869717        -3081055           NaN
# BADUM JAMES P           NaN            178980             NaN           NaN
# BANNANTINE JAMES M      NaN               NaN           -5104           NaN
# BAXTER JOHN C       1200000           1295738        -1386055           NaN
# BAY FRANKLIN R       400000            260455         -201641           NaN
#
#                                  email_address exercised_stock_options  \
# ALLEN PHILLIP K        phillip.allen@enron.com                 1729541
# BADUM JAMES P                              NaN                  257817
# BANNANTINE JAMES M  james.bannantine@enron.com                 4046157
# BAXTER JOHN C                              NaN                 6680544
# BAY FRANKLIN R             frank.bay@enron.com                     NaN
#
#                    expenses from_messages from_poi_to_this_person  \
# ALLEN PHILLIP K       13868          2195                      47
# BADUM JAMES P          3486           NaN                     NaN
# BANNANTINE JAMES M    56301            29                      39
# BAXTER JOHN C         11200           NaN                     NaN
# BAY FRANKLIN R       129142           NaN                     NaN
#
#                    from_this_person_to_poi        ...         \
# ALLEN PHILLIP K                         65        ...
# BADUM JAMES P                          NaN        ...
# BANNANTINE JAMES M                       0        ...
# BAXTER JOHN C                          NaN        ...
# BAY FRANKLIN R                         NaN        ...
#
#                    long_term_incentive    other    poi restricted_stock  \
# ALLEN PHILLIP K                 304805      152  False           126027
# BADUM JAMES P                      NaN      NaN  False              NaN
# BANNANTINE JAMES M                 NaN   864523  False          1757552
# BAXTER JOHN C                  1586055  2660303  False          3942714
# BAY FRANKLIN R                     NaN       69  False           145796
#
#                    restricted_stock_deferred  salary shared_receipt_with_poi  \
# ALLEN PHILLIP K                      -126027  201955                    1407
# BADUM JAMES P                            NaN     NaN                     NaN
# BANNANTINE JAMES M                   -560222     477                     465
# BAXTER JOHN C                            NaN  267102                     NaN
# BAY FRANKLIN R                        -82782  239671                     NaN
#
#                    to_messages total_payments total_stock_value
# ALLEN PHILLIP K           2902        4484442           1729541
# BADUM JAMES P              NaN         182466            257817
# BANNANTINE JAMES M         566         916197           5243487
# BAXTER JOHN C              NaN        5634343          10623258
# BAY FRANKLIN R             NaN         827696             63014
#
# [5 rows x 21 columns]

# %%
df_enron.describe()
# Out:
#        bonus deferral_payments deferred_income director_fees email_address  \
# count    146               146             146           146           146
# unique    42                40              45            18           112
# top      NaN               NaN             NaN           NaN           NaN
# freq      64               107              97           129            35
#
#        exercised_stock_options expenses from_messages from_poi_to_this_person  \
# count                      146      146           146                     146
# unique                     102       95            65                      58
# top                        NaN      NaN           NaN                     NaN
# freq                        44       51            60                      60
#
#        from_this_person_to_poi        ...        long_term_incentive other  \
# count                      146        ...                        146   146
# unique                      42        ...                         53    93
# top                        NaN        ...                        NaN   NaN
# freq                        60        ...                         80    53
#
#           poi restricted_stock restricted_stock_deferred salary  \
# count     146              146                       146    146
# unique      2               98                        19     95
# top     False              NaN                       NaN    NaN
# freq      128               36                       128     51
#
#        shared_receipt_with_poi to_messages total_payments total_stock_value
# count                      146         146            146               146
# unique                      84          87            126               125
# top                        NaN         NaN            NaN               NaN
# freq                        60          60             21                20
#
# [4 rows x 21 columns]

# %%
df_enron.shape
# Out:
# (146, 21)

# %%
print "There are ", len(data_dict.keys()), " executives in Enron Dataset."
# Out:
# There are  146  executives in Enron Dataset.

# %%
print data_dict.keys()
# Out:
# ['METTS MARK', 'BAXTER JOHN C', 'ELLIOTT STEVEN', 'CORDES WILLIAM R', 'HANNON KEVIN P', 'MORDAUNT KRISTINA M', 'MEYER ROCKFORD G', 'MCMAHON JEFFREY', 'HORTON STANLEY C', 'PIPER GREGORY F', 'HUMPHREY GENE E', 'UMANOFF ADAM S', 'BLACHMAN JEREMY M', 'SUNDE MARTIN', 'GIBBS DANA R', 'LOWRY CHARLES P', 'COLWELL WESLEY', 'MULLER MARK S', 'JACKSON CHARLENE R', 'WESTFAHL RICHARD K', 'WALTERS GARETH W', 'WALLS JR ROBERT H', 'KITCHEN LOUISE', 'CHAN RONNIE', 'BELFER ROBERT', 'SHANKMAN JEFFREY A', 'WODRASKA JOHN', 'BERGSIEKER RICHARD P', 'URQUHART JOHN A', 'BIBI PHILIPPE A', 'RIEKER PAULA H', 'WHALEY DAVID A', 'BECK SALLY W', 'HAUG DAVID L', 'ECHOLS JOHN B', 'MENDELSOHN JOHN', 'HICKERSON GARY J', 'CLINE KENNETH W', 'LEWIS RICHARD', 'HAYES ROBERT E', 'MCCARTY DANNY J', 'KOPPER MICHAEL J', 'LEFF DANIEL P', 'LAVORATO JOHN J', 'BERBERIAN DAVID', 'DETMERING TIMOTHY J', 'WAKEHAM JOHN', 'POWERS WILLIAM', 'GOLD JOSEPH', 'BANNANTINE JAMES M', 'DUNCAN JOHN H', 'SHAPIRO RICHARD S', 'SHERRIFF JOHN R', 'SHELBY REX', 'LEMAISTRE CHARLES', 'DEFFNER JOSEPH M', 'KISHKILL JOSEPH G', 'WHALLEY LAWRENCE G', 'MCCONNELL MICHAEL S', 'PIRO JIM', 'DELAINEY DAVID W', 'SULLIVAN-SHAKLOVITZ COLLEEN', 'WROBEL BRUCE', 'LINDHOLM TOD A', 'MEYER JEROME J', 'LAY KENNETH L', 'BUTTS ROBERT H', 'OLSON CINDY K', 'MCDONALD REBECCA', 'CUMBERLAND MICHAEL S', 'GAHN ROBERT S', 'MCCLELLAN GEORGE', 'HERMANN ROBERT J', 'SCRIMSHAW MATTHEW', 'GATHMANN WILLIAM D', 'HAEDICKE MARK E', 'BOWEN JR RAYMOND M', 'GILLIS JOHN', 'FITZGERALD JAY L', 'MORAN MICHAEL P', 'REDMOND BRIAN L', 'BAZELIDES PHILIP J', 'BELDEN TIMOTHY N', 'DURAN WILLIAM D', 'THORN TERENCE H', 'FASTOW ANDREW S', 'FOY JOE', 'CALGER CHRISTOPHER F', 'RICE KENNETH D', 'KAMINSKI WINCENTY J', 'LOCKHART EUGENE E', 'COX DAVID', 'OVERDYKE JR JERE C', 'PEREIRA PAULO V. FERRAZ', 'STABLER FRANK', 'SKILLING JEFFREY K', 'BLAKE JR. NORMAN P', 'SHERRICK JEFFREY B', 'PRENTICE JAMES', 'GRAY RODNEY', 'PICKERING MARK R', 'THE TRAVEL AGENCY IN THE PARK', 'NOLES JAMES L', 'KEAN STEVEN J', 'TOTAL', 'FOWLER PEGGY', 'WASAFF GEORGE', 'WHITE JR THOMAS E', 'CHRISTODOULOU DIOMEDES', 'ALLEN PHILLIP K', 'SHARP VICTORIA T', 'JAEDICKE ROBERT', 'WINOKUR JR. HERBERT S', 'BROWN MICHAEL', 'BADUM JAMES P', 'HUGHES JAMES A', 'REYNOLDS LAWRENCE', 'DIMICHELE RICHARD G', 'BHATNAGAR SANJAY', 'CARTER REBECCA C', 'BUCHANAN HAROLD G', 'YEAP SOON', 'MURRAY JULIA H', 'GARLAND C KEVIN', 'DODSON KEITH', 'YEAGER F SCOTT', 'HIRKO JOSEPH', 'DIETRICH JANET R', 'DERRICK JR. JAMES V', 'FREVERT MARK A', 'PAI LOU L', 'BAY FRANKLIN R', 'HAYSLETT RODERICK J', 'FUGH JOHN L', 'FALLON JAMES B', 'KOENIG MARK E', 'SAVAGE FRANK', 'IZZO LAWRENCE L', 'TILNEY ELIZABETH A', 'MARTIN AMANDA K', 'BUY RICHARD B', 'GRAMM WENDY L', 'CAUSEY RICHARD A', 'TAYLOR MITCHELL S', 'DONAHUE JR JEFFREY M', 'GLISAN JR BEN F']

# %% [markdown]
# # Explore Data

# %% [markdown]
# First I would like to visually look at the data and check if it contains any NaN values and/or outliers.

# %%
df_enron = df_enron.replace('NaN', np.nan)

# %%
print "Amount of NaN values in the dataset: ", df_enron.isnull().sum().sum()


df_enron.loc[(df_enron['email_address'].isnull()) |
              (df_enron['deferral_payments'].isnull()) |
              (df_enron['bonus'].isnull()) |
              (df_enron['from_messages'].isnull())]
# Out:
# Amount of NaN values in the dataset:  1358
#                                     bonus  deferral_payments  deferred_income  \
# BADUM JAMES P                         NaN           178980.0              NaN
# BANNANTINE JAMES M                    NaN                NaN          -5104.0
# BAXTER JOHN C                   1200000.0          1295738.0       -1386055.0
# BAY FRANKLIN R                   400000.0           260455.0        -201641.0
# BAZELIDES PHILIP J                    NaN           684694.0              NaN
# BECK SALLY W                     700000.0                NaN              NaN
# BELFER ROBERT                         NaN          -102500.0              NaN
# BERBERIAN DAVID                       NaN                NaN              NaN
# BERGSIEKER RICHARD P             250000.0                NaN        -485813.0
# BHATNAGAR SANJAY                      NaN                NaN              NaN
# BIBI PHILIPPE A                 1000000.0                NaN              NaN
# BLACHMAN JEREMY M                850000.0                NaN              NaN
# BLAKE JR. NORMAN P                    NaN                NaN        -113784.0
# BOWEN JR RAYMOND M              1350000.0                NaN           -833.0
# BROWN MICHAEL                         NaN                NaN              NaN
# BUCHANAN HAROLD G                500000.0                NaN              NaN
# BUTTS ROBERT H                   750000.0                NaN         -75000.0
# CALGER CHRISTOPHER F            1250000.0                NaN        -262500.0
# CARTER REBECCA C                 300000.0                NaN        -159792.0
# CAUSEY RICHARD A                1000000.0                NaN        -235000.0
# CHAN RONNIE                           NaN                NaN         -98784.0
# CHRISTODOULOU DIOMEDES                NaN                NaN              NaN
# CLINE KENNETH W                       NaN                NaN              NaN
# CORDES WILLIAM R                      NaN                NaN              NaN
# COX DAVID                        800000.0                NaN         -41250.0
# CUMBERLAND MICHAEL S             325000.0                NaN              NaN
# DEFFNER JOSEPH M                 600000.0                NaN              NaN
# DELAINEY DAVID W                3000000.0                NaN              NaN
# DERRICK JR. JAMES V              800000.0                NaN       -1284000.0
# DETMERING TIMOTHY J              425000.0           875307.0        -775241.0
# ...                                   ...                ...              ...
# RICE KENNETH D                  1750000.0                NaN       -3504386.0
# SAVAGE FRANK                          NaN                NaN        -121284.0
# SCRIMSHAW MATTHEW                     NaN                NaN              NaN
# SHANKMAN JEFFREY A              2000000.0                NaN              NaN
# SHAPIRO RICHARD S                650000.0                NaN              NaN
# SHELBY REX                       200000.0                NaN          -4167.0
# SHERRICK JEFFREY B                    NaN                NaN              NaN
# SHERRIFF JOHN R                 1500000.0                NaN              NaN
# SKILLING JEFFREY K              5600000.0                NaN              NaN
# STABLER FRANK                    500000.0                NaN              NaN
# SULLIVAN-SHAKLOVITZ COLLEEN      100000.0           181993.0              NaN
# SUNDE MARTIN                     700000.0                NaN              NaN
# THE TRAVEL AGENCY IN THE PARK         NaN                NaN              NaN
# THORN TERENCE H                       NaN            16586.0              NaN
# TILNEY ELIZABETH A               300000.0                NaN        -575000.0
# TOTAL                          97343619.0         32083396.0      -27992891.0
# UMANOFF ADAM S                   788750.0                NaN              NaN
# URQUHART JOHN A                       NaN                NaN         -36666.0
# WAKEHAM JOHN                          NaN                NaN              NaN
# WALLS JR ROBERT H                850000.0                NaN              NaN
# WALTERS GARETH W                      NaN            53625.0              NaN
# WESTFAHL RICHARD K                    NaN                NaN         -10800.0
# WHALEY DAVID A                        NaN                NaN              NaN
# WHALLEY LAWRENCE G              3000000.0                NaN              NaN
# WHITE JR THOMAS E                450000.0                NaN              NaN
# WINOKUR JR. HERBERT S                 NaN                NaN         -25000.0
# WODRASKA JOHN                         NaN                NaN              NaN
# WROBEL BRUCE                          NaN                NaN              NaN
# YEAGER F SCOTT                        NaN                NaN              NaN
# YEAP SOON                             NaN                NaN              NaN
#
#                                director_fees  \
# BADUM JAMES P                            NaN
# BANNANTINE JAMES M                       NaN
# BAXTER JOHN C                            NaN
# BAY FRANKLIN R                           NaN
# BAZELIDES PHILIP J                       NaN
# BECK SALLY W                             NaN
# BELFER ROBERT                         3285.0
# BERBERIAN DAVID                          NaN
# BERGSIEKER RICHARD P                     NaN
# BHATNAGAR SANJAY                    137864.0
# BIBI PHILIPPE A                          NaN
# BLACHMAN JEREMY M                        NaN
# BLAKE JR. NORMAN P                  113784.0
# BOWEN JR RAYMOND M                       NaN
# BROWN MICHAEL                            NaN
# BUCHANAN HAROLD G                        NaN
# BUTTS ROBERT H                           NaN
# CALGER CHRISTOPHER F                     NaN
# CARTER REBECCA C                         NaN
# CAUSEY RICHARD A                         NaN
# CHAN RONNIE                          98784.0
# CHRISTODOULOU DIOMEDES                   NaN
# CLINE KENNETH W                          NaN
# CORDES WILLIAM R                         NaN
# COX DAVID                                NaN
# CUMBERLAND MICHAEL S                     NaN
# DEFFNER JOSEPH M                         NaN
# DELAINEY DAVID W                         NaN
# DERRICK JR. JAMES V                      NaN
# DETMERING TIMOTHY J                      NaN
# ...                                      ...
# RICE KENNETH D                           NaN
# SAVAGE FRANK                        125034.0
# SCRIMSHAW MATTHEW                        NaN
# SHANKMAN JEFFREY A                       NaN
# SHAPIRO RICHARD S                        NaN
# SHELBY REX                               NaN
# SHERRICK JEFFREY B                       NaN
# SHERRIFF JOHN R                          NaN
# SKILLING JEFFREY K                       NaN
# STABLER FRANK                            NaN
# SULLIVAN-SHAKLOVITZ COLLEEN              NaN
# SUNDE MARTIN                             NaN
# THE TRAVEL AGENCY IN THE PARK            NaN
# THORN TERENCE H                          NaN
# TILNEY ELIZABETH A                       NaN
# TOTAL                              1398517.0
# UMANOFF ADAM S                           NaN
# URQUHART JOHN A                      36666.0
# WAKEHAM JOHN                        109298.0
# WALLS JR ROBERT H                        NaN
# WALTERS GARETH W                         NaN
# WESTFAHL RICHARD K                       NaN
# WHALEY DAVID A                           NaN
# WHALLEY LAWRENCE G                       NaN
# WHITE JR THOMAS E                        NaN
# WINOKUR JR. HERBERT S               108579.0
# WODRASKA JOHN                            NaN
# WROBEL BRUCE                             NaN
# YEAGER F SCOTT                           NaN
# YEAP SOON                                NaN
#
#                                                   email_address  \
# BADUM JAMES P                                               NaN
# BANNANTINE JAMES M                   james.bannantine@enron.com
# BAXTER JOHN C                                               NaN
# BAY FRANKLIN R                              frank.bay@enron.com
# BAZELIDES PHILIP J                                          NaN
# BECK SALLY W                               sally.beck@enron.com
# BELFER ROBERT                                               NaN
# BERBERIAN DAVID                       david.berberian@enron.com
# BERGSIEKER RICHARD P                  rick.bergsieker@enron.com
# BHATNAGAR SANJAY                     sanjay.bhatnagar@enron.com
# BIBI PHILIPPE A                         philippe.bibi@enron.com
# BLACHMAN JEREMY M                     jeremy.blachman@enron.com
# BLAKE JR. NORMAN P                                          NaN
# BOWEN JR RAYMOND M                      raymond.bowen@enron.com
# BROWN MICHAEL                           michael.brown@enron.com
# BUCHANAN HAROLD G                       john.buchanan@enron.com
# BUTTS ROBERT H                              bob.butts@enron.com
# CALGER CHRISTOPHER F               christopher.calger@enron.com
# CARTER REBECCA C                       rebecca.carter@enron.com
# CAUSEY RICHARD A                       richard.causey@enron.com
# CHAN RONNIE                                                 NaN
# CHRISTODOULOU DIOMEDES         diomedes.christodoulou@enron.com
# CLINE KENNETH W                                             NaN
# CORDES WILLIAM R                          bill.cordes@enron.com
# COX DAVID                                    chip.cox@enron.com
# CUMBERLAND MICHAEL S                                        NaN
# DEFFNER JOSEPH M                       joseph.deffner@enron.com
# DELAINEY DAVID W                       david.delainey@enron.com
# DERRICK JR. JAMES V                     james.derrick@enron.com
# DETMERING TIMOTHY J                 timothy.detmering@enron.com
# ...                                                         ...
# RICE KENNETH D                               ken.rice@enron.com
# SAVAGE FRANK                                                NaN
# SCRIMSHAW MATTHEW                   matthew.scrimshaw@enron.com
# SHANKMAN JEFFREY A                   jeffrey.shankman@enron.com
# SHAPIRO RICHARD S                     richard.shapiro@enron.com
# SHELBY REX                                 rex.shelby@enron.com
# SHERRICK JEFFREY B                   jeffrey.sherrick@enron.com
# SHERRIFF JOHN R                         john.sherriff@enron.com
# SKILLING JEFFREY K                      jeff.skilling@enron.com
# STABLER FRANK                           frank.stabler@enron.com
# SULLIVAN-SHAKLOVITZ COLLEEN                                 NaN
# SUNDE MARTIN                              marty.sunde@enron.com
# THE TRAVEL AGENCY IN THE PARK                               NaN
# THORN TERENCE H                         terence.thorn@enron.com
# TILNEY ELIZABETH A                   elizabeth.tilney@enron.com
# TOTAL                                                       NaN
# UMANOFF ADAM S                           adam.umanoff@enron.com
# URQUHART JOHN A                                             NaN
# WAKEHAM JOHN                                                NaN
# WALLS JR ROBERT H                           rob.walls@enron.com
# WALTERS GARETH W                                            NaN
# WESTFAHL RICHARD K                      dick.westfahl@enron.com
# WHALEY DAVID A                                              NaN
# WHALLEY LAWRENCE G                       greg.whalley@enron.com
# WHITE JR THOMAS E                        thomas.white@enron.com
# WINOKUR JR. HERBERT S                                       NaN
# WODRASKA JOHN                           john.wodraska@enron.com
# WROBEL BRUCE                                                NaN
# YEAGER F SCOTT                           scott.yeager@enron.com
# YEAP SOON                                                   NaN
#
#                                exercised_stock_options   expenses  \
# BADUM JAMES P                                 257817.0     3486.0
# BANNANTINE JAMES M                           4046157.0    56301.0
# BAXTER JOHN C                                6680544.0    11200.0
# BAY FRANKLIN R                                     NaN   129142.0
# BAZELIDES PHILIP J                           1599641.0        NaN
# BECK SALLY W                                       NaN    37172.0
# BELFER ROBERT                                   3285.0        NaN
# BERBERIAN DAVID                              1624396.0    11892.0
# BERGSIEKER RICHARD P                               NaN    59175.0
# BHATNAGAR SANJAY                             2604490.0        NaN
# BIBI PHILIPPE A                              1465734.0    38559.0
# BLACHMAN JEREMY M                             765313.0    84208.0
# BLAKE JR. NORMAN P                                 NaN     1279.0
# BOWEN JR RAYMOND M                                 NaN    65907.0
# BROWN MICHAEL                                      NaN    49288.0
# BUCHANAN HAROLD G                             825464.0      600.0
# BUTTS ROBERT H                                     NaN     9410.0
# CALGER CHRISTOPHER F                               NaN    35818.0
# CARTER REBECCA C                                   NaN        NaN
# CAUSEY RICHARD A                                   NaN    30674.0
# CHAN RONNIE                                        NaN        NaN
# CHRISTODOULOU DIOMEDES                       5127155.0        NaN
# CLINE KENNETH W                                    NaN        NaN
# CORDES WILLIAM R                              651850.0        NaN
# COX DAVID                                     117551.0    27861.0
# CUMBERLAND MICHAEL S                               NaN    22344.0
# DEFFNER JOSEPH M                               17378.0    41626.0
# DELAINEY DAVID W                             2291113.0    86174.0
# DERRICK JR. JAMES V                          8831913.0    51124.0
# DETMERING TIMOTHY J                          2027865.0    52255.0
# ...                                                ...        ...
# RICE KENNETH D                              19794175.0    46950.0
# SAVAGE FRANK                                       NaN        NaN
# SCRIMSHAW MATTHEW                             759557.0        NaN
# SHANKMAN JEFFREY A                           1441898.0   178979.0
# SHAPIRO RICHARD S                             607837.0   137767.0
# SHELBY REX                                   1624396.0    22884.0
# SHERRICK JEFFREY B                           1426469.0        NaN
# SHERRIFF JOHN R                              1835558.0        NaN
# SKILLING JEFFREY K                          19250000.0    29336.0
# STABLER FRANK                                      NaN    16514.0
# SULLIVAN-SHAKLOVITZ COLLEEN                  1362375.0        NaN
# SUNDE MARTIN                                       NaN        NaN
# THE TRAVEL AGENCY IN THE PARK                      NaN        NaN
# THORN TERENCE H                              4452476.0    46145.0
# TILNEY ELIZABETH A                            591250.0        NaN
# TOTAL                                      311764000.0  5235198.0
# UMANOFF ADAM S                                     NaN    53122.0
# URQUHART JOHN A                                    NaN   228656.0
# WAKEHAM JOHN                                       NaN   103773.0
# WALLS JR ROBERT H                            4346544.0    50936.0
# WALTERS GARETH W                             1030329.0    33785.0
# WESTFAHL RICHARD K                                 NaN    51870.0
# WHALEY DAVID A                                 98718.0        NaN
# WHALLEY LAWRENCE G                           3282960.0    57838.0
# WHITE JR THOMAS E                            1297049.0    81353.0
# WINOKUR JR. HERBERT S                              NaN     1413.0
# WODRASKA JOHN                                      NaN        NaN
# WROBEL BRUCE                                  139130.0        NaN
# YEAGER F SCOTT                               8308552.0    53947.0
# YEAP SOON                                     192758.0    55097.0
#
#                                from_messages  from_poi_to_this_person  \
# BADUM JAMES P                            NaN                      NaN
# BANNANTINE JAMES M                      29.0                     39.0
# BAXTER JOHN C                            NaN                      NaN
# BAY FRANKLIN R                           NaN                      NaN
# BAZELIDES PHILIP J                       NaN                      NaN
# BECK SALLY W                          4343.0                    144.0
# BELFER ROBERT                            NaN                      NaN
# BERBERIAN DAVID                          NaN                      NaN
# BERGSIEKER RICHARD P                    59.0                      4.0
# BHATNAGAR SANJAY                        29.0                      0.0
# BIBI PHILIPPE A                         40.0                     23.0
# BLACHMAN JEREMY M                       14.0                     25.0
# BLAKE JR. NORMAN P                       NaN                      NaN
# BOWEN JR RAYMOND M                      27.0                    140.0
# BROWN MICHAEL                           41.0                     13.0
# BUCHANAN HAROLD G                      125.0                      0.0
# BUTTS ROBERT H                           NaN                      NaN
# CALGER CHRISTOPHER F                   144.0                    199.0
# CARTER REBECCA C                        15.0                     29.0
# CAUSEY RICHARD A                        49.0                     58.0
# CHAN RONNIE                              NaN                      NaN
# CHRISTODOULOU DIOMEDES                   NaN                      NaN
# CLINE KENNETH W                          NaN                      NaN
# CORDES WILLIAM R                        12.0                     10.0
# COX DAVID                               33.0                      0.0
# CUMBERLAND MICHAEL S                     NaN                      NaN
# DEFFNER JOSEPH M                        74.0                    115.0
# DELAINEY DAVID W                      3069.0                     66.0
# DERRICK JR. JAMES V                    909.0                     64.0
# DETMERING TIMOTHY J                      NaN                      NaN
# ...                                      ...                      ...
# RICE KENNETH D                          18.0                     42.0
# SAVAGE FRANK                             NaN                      NaN
# SCRIMSHAW MATTHEW                        NaN                      NaN
# SHANKMAN JEFFREY A                    2681.0                     94.0
# SHAPIRO RICHARD S                     1215.0                     74.0
# SHELBY REX                              39.0                     13.0
# SHERRICK JEFFREY B                      25.0                     39.0
# SHERRIFF JOHN R                         92.0                     28.0
# SKILLING JEFFREY K                     108.0                     88.0
# STABLER FRANK                            NaN                      NaN
# SULLIVAN-SHAKLOVITZ COLLEEN              NaN                      NaN
# SUNDE MARTIN                            38.0                     37.0
# THE TRAVEL AGENCY IN THE PARK            NaN                      NaN
# THORN TERENCE H                         41.0                      0.0
# TILNEY ELIZABETH A                      19.0                     10.0
# TOTAL                                    NaN                      NaN
# UMANOFF ADAM S                          18.0                     12.0
# URQUHART JOHN A                          NaN                      NaN
# WAKEHAM JOHN                             NaN                      NaN
# WALLS JR ROBERT H                      146.0                     17.0
# WALTERS GARETH W                         NaN                      NaN
# WESTFAHL RICHARD K                       NaN                      NaN
# WHALEY DAVID A                           NaN                      NaN
# WHALLEY LAWRENCE G                     556.0                    186.0
# WHITE JR THOMAS E                        NaN                      NaN
# WINOKUR JR. HERBERT S                    NaN                      NaN
# WODRASKA JOHN                            NaN                      NaN
# WROBEL BRUCE                             NaN                      NaN
# YEAGER F SCOTT                           NaN                      NaN
# YEAP SOON                                NaN                      NaN
#
#                                from_this_person_to_poi        ...          \
# BADUM JAMES P                                      NaN        ...
# BANNANTINE JAMES M                                 0.0        ...
# BAXTER JOHN C                                      NaN        ...
# BAY FRANKLIN R                                     NaN        ...
# BAZELIDES PHILIP J                                 NaN        ...
# BECK SALLY W                                     386.0        ...
# BELFER ROBERT                                      NaN        ...
# BERBERIAN DAVID                                    NaN        ...
# BERGSIEKER RICHARD P                               0.0        ...
# BHATNAGAR SANJAY                                   1.0        ...
# BIBI PHILIPPE A                                    8.0        ...
# BLACHMAN JEREMY M                                  2.0        ...
# BLAKE JR. NORMAN P                                 NaN        ...
# BOWEN JR RAYMOND M                                15.0        ...
# BROWN MICHAEL                                      1.0        ...
# BUCHANAN HAROLD G                                  0.0        ...
# BUTTS ROBERT H                                     NaN        ...
# CALGER CHRISTOPHER F                              25.0        ...
# CARTER REBECCA C                                   7.0        ...
# CAUSEY RICHARD A                                  12.0        ...
# CHAN RONNIE                                        NaN        ...
# CHRISTODOULOU DIOMEDES                             NaN        ...
# CLINE KENNETH W                                    NaN        ...
# CORDES WILLIAM R                                   0.0        ...
# COX DAVID                                          4.0        ...
# CUMBERLAND MICHAEL S                               NaN        ...
# DEFFNER JOSEPH M                                   4.0        ...
# DELAINEY DAVID W                                 609.0        ...
# DERRICK JR. JAMES V                               20.0        ...
# DETMERING TIMOTHY J                                NaN        ...
# ...                                                ...        ...
# RICE KENNETH D                                     4.0        ...
# SAVAGE FRANK                                       NaN        ...
# SCRIMSHAW MATTHEW                                  NaN        ...
# SHANKMAN JEFFREY A                                83.0        ...
# SHAPIRO RICHARD S                                 65.0        ...
# SHELBY REX                                        14.0        ...
# SHERRICK JEFFREY B                                18.0        ...
# SHERRIFF JOHN R                                   23.0        ...
# SKILLING JEFFREY K                                30.0        ...
# STABLER FRANK                                      NaN        ...
# SULLIVAN-SHAKLOVITZ COLLEEN                        NaN        ...
# SUNDE MARTIN                                      13.0        ...
# THE TRAVEL AGENCY IN THE PARK                      NaN        ...
# THORN TERENCE H                                    0.0        ...
# TILNEY ELIZABETH A                                11.0        ...
# TOTAL                                              NaN        ...
# UMANOFF ADAM S                                     0.0        ...
# URQUHART JOHN A                                    NaN        ...
# WAKEHAM JOHN                                       NaN        ...
# WALLS JR ROBERT H                                  0.0        ...
# WALTERS GARETH W                                   NaN        ...
# WESTFAHL RICHARD K                                 NaN        ...
# WHALEY DAVID A                                     NaN        ...
# WHALLEY LAWRENCE G                                24.0        ...
# WHITE JR THOMAS E                                  NaN        ...
# WINOKUR JR. HERBERT S                              NaN        ...
# WODRASKA JOHN                                      NaN        ...
# WROBEL BRUCE                                       NaN        ...
# YEAGER F SCOTT                                     NaN        ...
# YEAP SOON                                          NaN        ...
#
#                                long_term_incentive       other    poi  \
# BADUM JAMES P                                  NaN         NaN  False
# BANNANTINE JAMES M                             NaN    864523.0  False
# BAXTER JOHN C                            1586055.0   2660303.0  False
# BAY FRANKLIN R                                 NaN        69.0  False
# BAZELIDES PHILIP J                         93750.0       874.0  False
# BECK SALLY W                                   NaN       566.0  False
# BELFER ROBERT                                  NaN         NaN  False
# BERBERIAN DAVID                                NaN         NaN  False
# BERGSIEKER RICHARD P                      180250.0    427316.0  False
# BHATNAGAR SANJAY                               NaN    137864.0  False
# BIBI PHILIPPE A                           369721.0    425688.0  False
# BLACHMAN JEREMY M                         831809.0       272.0  False
# BLAKE JR. NORMAN P                             NaN         NaN  False
# BOWEN JR RAYMOND M                        974293.0      1621.0   True
# BROWN MICHAEL                                  NaN         NaN  False
# BUCHANAN HAROLD G                         304805.0      1215.0  False
# BUTTS ROBERT H                            175000.0    150656.0  False
# CALGER CHRISTOPHER F                      375304.0       486.0   True
# CARTER REBECCA C                           75000.0       540.0  False
# CAUSEY RICHARD A                          350000.0    307895.0   True
# CHAN RONNIE                                    NaN         NaN  False
# CHRISTODOULOU DIOMEDES                         NaN         NaN  False
# CLINE KENNETH W                                NaN         NaN  False
# CORDES WILLIAM R                               NaN         NaN  False
# COX DAVID                                      NaN       494.0  False
# CUMBERLAND MICHAEL S                      275000.0       713.0  False
# DEFFNER JOSEPH M                          335349.0     25553.0  False
# DELAINEY DAVID W                         1294981.0      1661.0   True
# DERRICK JR. JAMES V                       484000.0      7482.0  False
# DETMERING TIMOTHY J                       415657.0      1105.0  False
# ...                                            ...         ...    ...
# RICE KENNETH D                           1617011.0    174839.0   True
# SAVAGE FRANK                                   NaN         NaN  False
# SCRIMSHAW MATTHEW                              NaN         NaN  False
# SHANKMAN JEFFREY A                        554422.0      1191.0  False
# SHAPIRO RICHARD S                              NaN       705.0  False
# SHELBY REX                                     NaN   1573324.0   True
# SHERRICK JEFFREY B                             NaN         NaN  False
# SHERRIFF JOHN R                           554422.0   1852186.0  False
# SKILLING JEFFREY K                       1920000.0     22122.0   True
# STABLER FRANK                                  NaN    356071.0  False
# SULLIVAN-SHAKLOVITZ COLLEEN               554422.0       162.0  False
# SUNDE MARTIN                              476451.0    111122.0  False
# THE TRAVEL AGENCY IN THE PARK                  NaN    362096.0  False
# THORN TERENCE H                           200000.0    426629.0  False
# TILNEY ELIZABETH A                        275000.0    152055.0  False
# TOTAL                                   48521928.0  42667589.0  False
# UMANOFF ADAM S                                 NaN         NaN  False
# URQUHART JOHN A                                NaN         NaN  False
# WAKEHAM JOHN                                   NaN         NaN  False
# WALLS JR ROBERT H                         540751.0         2.0  False
# WALTERS GARETH W                               NaN         NaN  False
# WESTFAHL RICHARD K                        256191.0    401130.0  False
# WHALEY DAVID A                                 NaN         NaN  False
# WHALLEY LAWRENCE G                        808346.0    301026.0  False
# WHITE JR THOMAS E                              NaN   1085463.0  False
# WINOKUR JR. HERBERT S                          NaN         NaN  False
# WODRASKA JOHN                                  NaN    189583.0  False
# WROBEL BRUCE                                   NaN         NaN  False
# YEAGER F SCOTT                                 NaN    147950.0   True
# YEAP SOON                                      NaN         NaN  False
#
#                                restricted_stock  restricted_stock_deferred  \
# BADUM JAMES P                               NaN                        NaN
# BANNANTINE JAMES M                    1757552.0                  -560222.0
# BAXTER JOHN C                         3942714.0                        NaN
# BAY FRANKLIN R                         145796.0                   -82782.0
# BAZELIDES PHILIP J                          NaN                        NaN
# BECK SALLY W                           126027.0                        NaN
# BELFER ROBERT                               NaN                    44093.0
# BERBERIAN DAVID                        869220.0                        NaN
# BERGSIEKER RICHARD P                   659249.0                        NaN
# BHATNAGAR SANJAY                     -2604490.0                 15456290.0
# BIBI PHILIPPE A                        378082.0                        NaN
# BLACHMAN JEREMY M                      189041.0                        NaN
# BLAKE JR. NORMAN P                          NaN                        NaN
# BOWEN JR RAYMOND M                     252055.0                        NaN
# BROWN MICHAEL                               NaN                        NaN
# BUCHANAN HAROLD G                      189041.0                        NaN
# BUTTS ROBERT H                         417619.0                        NaN
# CALGER CHRISTOPHER F                   126027.0                        NaN
# CARTER REBECCA C                       307301.0                  -307301.0
# CAUSEY RICHARD A                      2502063.0                        NaN
# CHAN RONNIE                             32460.0                   -32460.0
# CHRISTODOULOU DIOMEDES                 950730.0                        NaN
# CLINE KENNETH W                        662086.0                  -472568.0
# CORDES WILLIAM R                       386335.0                        NaN
# COX DAVID                              378082.0                        NaN
# CUMBERLAND MICHAEL S                   207940.0                        NaN
# DEFFNER JOSEPH M                       141833.0                        NaN
# DELAINEY DAVID W                      1323148.0                        NaN
# DERRICK JR. JAMES V                   1787380.0                 -1787380.0
# DETMERING TIMOTHY J                    315068.0                  -315068.0
# ...                                         ...                        ...
# RICE KENNETH D                        2748364.0                        NaN
# SAVAGE FRANK                                NaN                        NaN
# SCRIMSHAW MATTHEW                           NaN                        NaN
# SHANKMAN JEFFREY A                     630137.0                        NaN
# SHAPIRO RICHARD S                      379164.0                        NaN
# SHELBY REX                             869220.0                        NaN
# SHERRICK JEFFREY B                     405999.0                        NaN
# SHERRIFF JOHN R                       1293424.0                        NaN
# SKILLING JEFFREY K                    6843672.0                        NaN
# STABLER FRANK                          511734.0                        NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                 NaN                        NaN
# SUNDE MARTIN                           698920.0                        NaN
# THE TRAVEL AGENCY IN THE PARK               NaN                        NaN
# THORN TERENCE H                        365320.0                        NaN
# TILNEY ELIZABETH A                     576792.0                        NaN
# TOTAL                               130322299.0                 -7576788.0
# UMANOFF ADAM S                              NaN                        NaN
# URQUHART JOHN A                             NaN                        NaN
# WAKEHAM JOHN                                NaN                        NaN
# WALLS JR ROBERT H                     1552453.0                        NaN
# WALTERS GARETH W                            NaN                        NaN
# WESTFAHL RICHARD K                     384930.0                        NaN
# WHALEY DAVID A                              NaN                        NaN
# WHALLEY LAWRENCE G                    2796177.0                        NaN
# WHITE JR THOMAS E                    13847074.0                        NaN
# WINOKUR JR. HERBERT S                       NaN                        NaN
# WODRASKA JOHN                               NaN                        NaN
# WROBEL BRUCE                                NaN                        NaN
# YEAGER F SCOTT                        3576206.0                        NaN
# YEAP SOON                                   NaN                        NaN
#
#                                    salary  shared_receipt_with_poi  \
# BADUM JAMES P                         NaN                      NaN
# BANNANTINE JAMES M                  477.0                    465.0
# BAXTER JOHN C                    267102.0                      NaN
# BAY FRANKLIN R                   239671.0                      NaN
# BAZELIDES PHILIP J                80818.0                      NaN
# BECK SALLY W                     231330.0                   2639.0
# BELFER ROBERT                         NaN                      NaN
# BERBERIAN DAVID                  216582.0                      NaN
# BERGSIEKER RICHARD P             187922.0                    233.0
# BHATNAGAR SANJAY                      NaN                    463.0
# BIBI PHILIPPE A                  213625.0                   1336.0
# BLACHMAN JEREMY M                248546.0                   2326.0
# BLAKE JR. NORMAN P                    NaN                      NaN
# BOWEN JR RAYMOND M               278601.0                   1593.0
# BROWN MICHAEL                         NaN                    761.0
# BUCHANAN HAROLD G                248017.0                     23.0
# BUTTS ROBERT H                   261516.0                      NaN
# CALGER CHRISTOPHER F             240189.0                   2188.0
# CARTER REBECCA C                 261809.0                    196.0
# CAUSEY RICHARD A                 415189.0                   1585.0
# CHAN RONNIE                           NaN                      NaN
# CHRISTODOULOU DIOMEDES                NaN                      NaN
# CLINE KENNETH W                       NaN                      NaN
# CORDES WILLIAM R                      NaN                     58.0
# COX DAVID                        314288.0                     71.0
# CUMBERLAND MICHAEL S             184899.0                      NaN
# DEFFNER JOSEPH M                 206121.0                    552.0
# DELAINEY DAVID W                 365163.0                   2097.0
# DERRICK JR. JAMES V              492375.0                   1401.0
# DETMERING TIMOTHY J              210500.0                      NaN
# ...                                   ...                      ...
# RICE KENNETH D                   420636.0                    864.0
# SAVAGE FRANK                          NaN                      NaN
# SCRIMSHAW MATTHEW                     NaN                      NaN
# SHANKMAN JEFFREY A               304110.0                   1730.0
# SHAPIRO RICHARD S                269076.0                   4527.0
# SHELBY REX                       211844.0                     91.0
# SHERRICK JEFFREY B                    NaN                    583.0
# SHERRIFF JOHN R                  428780.0                   2103.0
# SKILLING JEFFREY K              1111258.0                   2042.0
# STABLER FRANK                    239502.0                      NaN
# SULLIVAN-SHAKLOVITZ COLLEEN      162779.0                      NaN
# SUNDE MARTIN                     257486.0                   2565.0
# THE TRAVEL AGENCY IN THE PARK         NaN                      NaN
# THORN TERENCE H                  222093.0                     73.0
# TILNEY ELIZABETH A               247338.0                    379.0
# TOTAL                          26704229.0                      NaN
# UMANOFF ADAM S                   288589.0                     41.0
# URQUHART JOHN A                       NaN                      NaN
# WAKEHAM JOHN                          NaN                      NaN
# WALLS JR ROBERT H                357091.0                    215.0
# WALTERS GARETH W                      NaN                      NaN
# WESTFAHL RICHARD K                63744.0                      NaN
# WHALEY DAVID A                        NaN                      NaN
# WHALLEY LAWRENCE G               510364.0                   3920.0
# WHITE JR THOMAS E                317543.0                      NaN
# WINOKUR JR. HERBERT S                 NaN                      NaN
# WODRASKA JOHN                         NaN                      NaN
# WROBEL BRUCE                          NaN                      NaN
# YEAGER F SCOTT                   158403.0                      NaN
# YEAP SOON                             NaN                      NaN
#
#                                to_messages  total_payments  total_stock_value
# BADUM JAMES P                          NaN        182466.0           257817.0
# BANNANTINE JAMES M                   566.0        916197.0          5243487.0
# BAXTER JOHN C                          NaN       5634343.0         10623258.0
# BAY FRANKLIN R                         NaN        827696.0            63014.0
# BAZELIDES PHILIP J                     NaN        860136.0          1599641.0
# BECK SALLY W                        7315.0        969068.0           126027.0
# BELFER ROBERT                          NaN        102500.0           -44093.0
# BERBERIAN DAVID                        NaN        228474.0          2493616.0
# BERGSIEKER RICHARD P                 383.0        618850.0           659249.0
# BHATNAGAR SANJAY                     523.0      15456290.0                NaN
# BIBI PHILIPPE A                     1607.0       2047593.0          1843816.0
# BLACHMAN JEREMY M                   2475.0       2014835.0           954354.0
# BLAKE JR. NORMAN P                     NaN          1279.0                NaN
# BOWEN JR RAYMOND M                  1858.0       2669589.0           252055.0
# BROWN MICHAEL                       1486.0         49288.0                NaN
# BUCHANAN HAROLD G                   1088.0       1054637.0          1014505.0
# BUTTS ROBERT H                         NaN       1271582.0           417619.0
# CALGER CHRISTOPHER F                2598.0       1639297.0           126027.0
# CARTER REBECCA C                     312.0        477557.0                NaN
# CAUSEY RICHARD A                    1892.0       1868758.0          2502063.0
# CHAN RONNIE                            NaN             NaN                NaN
# CHRISTODOULOU DIOMEDES                 NaN             NaN          6077885.0
# CLINE KENNETH W                        NaN             NaN           189518.0
# CORDES WILLIAM R                     764.0             NaN          1038185.0
# COX DAVID                            102.0       1101393.0           495633.0
# CUMBERLAND MICHAEL S                   NaN        807956.0           207940.0
# DEFFNER JOSEPH M                     714.0       1208649.0           159211.0
# DELAINEY DAVID W                    3093.0       4747979.0          3614261.0
# DERRICK JR. JAMES V                 2181.0        550981.0          8831913.0
# DETMERING TIMOTHY J                    NaN       1204583.0          2027865.0
# ...                                    ...             ...                ...
# RICE KENNETH D                       905.0        505050.0         22542539.0
# SAVAGE FRANK                           NaN          3750.0                NaN
# SCRIMSHAW MATTHEW                      NaN             NaN           759557.0
# SHANKMAN JEFFREY A                  3221.0       3038702.0          2072035.0
# SHAPIRO RICHARD S                  15149.0       1057548.0           987001.0
# SHELBY REX                           225.0       2003885.0          2493616.0
# SHERRICK JEFFREY B                   613.0             NaN          1832468.0
# SHERRIFF JOHN R                     3187.0       4335388.0          3128982.0
# SKILLING JEFFREY K                  3627.0       8682716.0         26093672.0
# STABLER FRANK                          NaN       1112087.0           511734.0
# SULLIVAN-SHAKLOVITZ COLLEEN            NaN        999356.0          1362375.0
# SUNDE MARTIN                        2647.0       1545059.0           698920.0
# THE TRAVEL AGENCY IN THE PARK          NaN        362096.0                NaN
# THORN TERENCE H                      266.0        911453.0          4817796.0
# TILNEY ELIZABETH A                   460.0        399393.0          1168042.0
# TOTAL                                  NaN     309886585.0        434509511.0
# UMANOFF ADAM S                       111.0       1130461.0                NaN
# URQUHART JOHN A                        NaN        228656.0                NaN
# WAKEHAM JOHN                           NaN        213071.0                NaN
# WALLS JR ROBERT H                    671.0       1798780.0          5898997.0
# WALTERS GARETH W                       NaN         87410.0          1030329.0
# WESTFAHL RICHARD K                     NaN        762135.0           384930.0
# WHALEY DAVID A                         NaN             NaN            98718.0
# WHALLEY LAWRENCE G                  6019.0       4677574.0          6079137.0
# WHITE JR THOMAS E                      NaN       1934359.0         15144123.0
# WINOKUR JR. HERBERT S                  NaN         84992.0                NaN
# WODRASKA JOHN                          NaN        189583.0                NaN
# WROBEL BRUCE                           NaN             NaN           139130.0
# YEAGER F SCOTT                         NaN        360300.0         11884758.0
# YEAP SOON                              NaN         55097.0           192758.0
#
# [132 rows x 21 columns]

# %%
df_enron = df_enron.fillna(0, axis=1)

df_enron.head(5)
# Out:
#                         bonus  deferral_payments  deferred_income  \
# ALLEN PHILLIP K     4175000.0          2869717.0       -3081055.0
# BADUM JAMES P             0.0           178980.0              0.0
# BANNANTINE JAMES M        0.0                0.0          -5104.0
# BAXTER JOHN C       1200000.0          1295738.0       -1386055.0
# BAY FRANKLIN R       400000.0           260455.0        -201641.0
#
#                     director_fees               email_address  \
# ALLEN PHILLIP K               0.0     phillip.allen@enron.com
# BADUM JAMES P                 0.0                           0
# BANNANTINE JAMES M            0.0  james.bannantine@enron.com
# BAXTER JOHN C                 0.0                           0
# BAY FRANKLIN R                0.0         frank.bay@enron.com
#
#                     exercised_stock_options  expenses  from_messages  \
# ALLEN PHILLIP K                   1729541.0   13868.0         2195.0
# BADUM JAMES P                      257817.0    3486.0            0.0
# BANNANTINE JAMES M                4046157.0   56301.0           29.0
# BAXTER JOHN C                     6680544.0   11200.0            0.0
# BAY FRANKLIN R                          0.0  129142.0            0.0
#
#                     from_poi_to_this_person  from_this_person_to_poi  \
# ALLEN PHILLIP K                        47.0                     65.0
# BADUM JAMES P                           0.0                      0.0
# BANNANTINE JAMES M                     39.0                      0.0
# BAXTER JOHN C                           0.0                      0.0
# BAY FRANKLIN R                          0.0                      0.0
#
#                           ...          long_term_incentive      other    poi  \
# ALLEN PHILLIP K           ...                     304805.0      152.0  False
# BADUM JAMES P             ...                          0.0        0.0  False
# BANNANTINE JAMES M        ...                          0.0   864523.0  False
# BAXTER JOHN C             ...                    1586055.0  2660303.0  False
# BAY FRANKLIN R            ...                          0.0       69.0  False
#
#                     restricted_stock  restricted_stock_deferred    salary  \
# ALLEN PHILLIP K             126027.0                  -126027.0  201955.0
# BADUM JAMES P                    0.0                        0.0       0.0
# BANNANTINE JAMES M         1757552.0                  -560222.0     477.0
# BAXTER JOHN C              3942714.0                        0.0  267102.0
# BAY FRANKLIN R              145796.0                   -82782.0  239671.0
#
#                     shared_receipt_with_poi  to_messages  total_payments  \
# ALLEN PHILLIP K                      1407.0       2902.0       4484442.0
# BADUM JAMES P                           0.0          0.0        182466.0
# BANNANTINE JAMES M                    465.0        566.0        916197.0
# BAXTER JOHN C                           0.0          0.0       5634343.0
# BAY FRANKLIN R                          0.0          0.0        827696.0
#
#                     total_stock_value
# ALLEN PHILLIP K             1729541.0
# BADUM JAMES P                257817.0
# BANNANTINE JAMES M          5243487.0
# BAXTER JOHN C              10623258.0
# BAY FRANKLIN R                63014.0
#
# [5 rows x 21 columns]

# %%
sb.pairplot(df_enron, hue='poi')

# %%
df_enron.plot.scatter(x='salary', y='bonus', color='steelblue');

# %%
# Remove any outliers before proceeding further
- tex: # This line drops any 'Iris-setosa' rows with a separal width less than 2.5 cm
iris_data = iris_data.loc[(iris_data['class'] != 'Iris-setosa') | (iris_data['sepal_width_cm'] >= 2.5)]
iris_data.loc[iris_data['class'] == 'Iris-setosa', 'sepal_width_cm'].hist()
# Out:
#   File "<ipython-input-19-01f2897ad72e>", line 2
#     - tex: # This line drops any 'Iris-setosa' rows with a separal width less than 2.5 cm
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Feature engineering

# %%
- Do correlation
- Feature Selection
-

# %%
features_list = ['poi','salary', 'bonus', 'total_stock_value', 'from_poi_to_this_person', 'from_this_person_to_poi'] 




maybe? = ["poi", "salary", "bonus", "fraction_from_poi_email", "fraction_to_poi_email", 'deferral_payments', 'total_payments', 'loan_advances', 'restricted_stock_deferred', 'deferred_income', 'total_stock_value']

# %% [markdown]
# # Classifiers

# %%
To do:
- Feature importence
- Precision/recall
-

# %%
df_enron = df_enron.drop([''], axis=1)

# %%
# Create the classifier

#clf = DecisionTreeClassifier()
clf = RFC(n_estimators=10)
#clf = SVC(C=500)
clf

# %%
feature_list = []

# %%
X = df_enron[feature_list].values
Y = df_enron['poi'].values

# %%
(training_inputs, testing_inputs, training_scores, testing_scores) = train_test_split(X, Y, test_size=0.75, random_state=43)

# %%
clf.fit(training_inputs, training_scores);

# %%
clf.score(testing_inputs, testing_scores)

# %% [markdown]
# # Validation

# %%
# Dump the classifier, dataset and features_list so anyone can run/check your results
pickle.dump(clf, open("my_classifier.pkl", "w") )
pickle.dump(data_dict, open("my_dataset.pkl", "w") )
pickle.dump(features_list, open("my_feature_list.pkl", "w") )

# %%
#!jupyter nbconvert --to script FinalProject_TheEnronFraud.ipynb
